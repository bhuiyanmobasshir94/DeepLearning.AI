# %%
research_decription="""
Research Project
============== 
1. KhaoDao Recommendation Engine: Led KRE design & ML development with Surprise/Implicit libraries. Transitioned to DLRM for cold start & sparse data, enhancing contextualized, hybrid recommendations.
2. Categorized Affect Map: Created ”Categorized Affect Map” GIS app, uncovering spatial-emotion insights and blending GIS expertise with ML auto-feature engineering. Led thesis group to project success.
3. Bengali WordNet: Led Bengali WordNet project, supervised team, improved linguistic resources, and excelled in project management.

Research Paper
==============
1. ”CID: Cow Images Dataset for Regression and Classification”
2. ”CAM - Categorized Affect Map: Implementation of a Smart Geographic Information System for Categorizing Places
Based on People’s Affective Responses”

Professional Research Project
============================
1. RecSys: Led ML-based SaaS development for versatile recommendations. Users create projects with masked datasets, train
models, evaluate, and conduct inference. Credits via Stripe cover training, storage, and API usage.
2. KhaoDao AI Feedback Assessment System: Led KAIFAS development with prompt engineering and GPT models,
streamlining customer feedback evaluation across departments, extracting sentiment, emotions, and insights.
3. KhaoDao AI Chatbot: Led KhaoDao Chatbot development, LLM-powered for orders and platform-specific help,
highlighting my expertise in conversational AI for superior user experiences.
4. Text Cluster Classifier: Designed ML model to cluster text in PDFs, structuring as obligations for ontology modeling and
system integration.
5. Metadata Extractor: Created ML model for extracting named entities from unstructured data using metadata dictionaries,
showcasing strong data engineering and NLP skills.
6. Rule Recognizer: Engineered Rule Recognizer using ML, custom dataset, and POS frequency tables for rule extraction,
enhancing obligation analysis.
7. Workflow Manager: Developed a versatile Workflow Manager integrating Apache Kafka and Apache Airflow for dynamic
DAG creation and task execution.
8. Renforce AI Management Platform: Developed Renforce AI Management Platform for end-to-end model management,
training, development, deployment, and monitoring.
9.Qesfera: Developed a financial ML app for credit risk modeling. Enhanced it with interactive dataset visualizers, prediction
analyzers, and reporting capabilities.
10. KhaoDao Recommendation Engine: Elevated KhaoDao Recommendation Engine with real-time, low-latency predictions
using DLRM framework. Spearheaded efficient online predictions for superior user experiences.
11. KhaoDao Menu Digitization AI: Developed KhaoDao Menu Digitization AI using PyTorch. Windows-based tool for
precise, efficient menu digitization in Bengali and English languages.
12. KhaoDao KYC: Created KhaoDao KYC, a PyTorch-based OCR app for Bengali and English, offering web-based service.
Applied computer vision for efficient document processing.
13. Smart Guess: Utilized MRCNN for cow measurements via instance segmentation in computer vision. Implemented
multi-input-output network using Keras functional API, predicting height, length, weight, and breed.
14. Qesfera Credit Risk Modeling: Developed Qesfera Credit Risk Model using advanced ML techniques for cutting-edge
credit risk analysis, emphasizing auto feature engineering.
15. KhaoDao BI Report: Utilized PowerBI to create comprehensive analytic reports, synthesizing customer data including
quantitative, qualitative, market, and internal insights for business teams.
"""

# %%
prompt = f"""
Your task is to generate a short summary of a reasearch description \
from a resume to propose a research proposal to the \
Professor for determining the competency of the candidate \
for the PhD program.  

Summarize the research description below, delimited by triple 
backticks, in at most 30 words, and focusing on any aspects \
that are relevant to the research related to AI. 

Research Description: ```{research_decription}```
"""

response = get_completion(prompt)
print(response)

# %%
prompt = f"""
Your task is to generate a short summary of a reasearch description.

Summarize the research description below, delimited by triple 
backticks, in at most 30 words, and focusing on any aspects \
that are relevant to the research related to AI. 

Research Description: 
```
The candidate has experience in developing recommendation engines, GIS applications, linguistic resources, and ML models for various AI-related projects. They have also worked on projects involving conversational AI, NLP, computer vision, and credit risk modeling.
```
"""

response = get_completion(prompt)
print(response)

# %%
prompt = f"""
Your task is to generate a short summary of a reasearch description \
from a resume to propose a research proposal. 

Summarize the research description below, delimited by triple 
backticks, in at most 30 words, and focusing on any aspects \
that are relevant to the research prospects related to AI. 

Research Description: ```{research_decription}```
"""

response = get_completion(prompt)
print(response)

# %%
prompt = f"""
Your task is to extract relevant information from \ 
from a resume to propose a research proposal to the \
Professor for determining the competency of the candidate \
for the PhD program.  

From the research description below, delimited by triple quotes \
extract the information relevant to AI research domains. \ 
Limit to 30 words. 

Research Description: ```{research_decription}```
"""

response = get_completion(prompt)
print(response)

# %%
email= """

Subject: Ph.D. Application Inquiry - Mobasshir Bhuiya Shagor

Dear [Professor's Last Name],

I trust this email finds you in good health. My name is Mobasshir Bhuiya Shagor, and I am enthusiastic about the opportunity to pursue a Ph.D. in Graduate Studies at Indiana University Bloomington starting in the Fall 2024 semester.

I hold a Bachelor of Science degree in Computer Science & Engineering from the American International University Bangladesh (AIUB), where I achieved a commendable GPA of 3.49 out of 4.00.

My academic journey includes the publication of my undergraduate thesis, titled "CAM - Categorized Affect Map: Implementation of a Smart Geographic Information System for Categorizing Places Based on People’s Affective Responses," as well as my professional research dataset, "CID: Cow Images Dataset for Regression and Classification," both presented at the esteemed ACM International Conference on Computing Advancements. Currently, I am actively involved in expanding and enhancing this dataset.

Professionally, I serve as a machine learning engineer at Graaho, a Virginia-based startup committed to advancing cutting-edge technologies. My previous roles include a tenure as a machine learning lead at Renforce for over a year and a three-year stint as a data scientist at Graaho. In these positions, I conducted research, developed applications across diverse domains, including machine learning and edge technologies, and played a pivotal role in establishing essential infrastructure for production data and machine learning systems.

I have had the opportunity to explore your research, which closely aligns with my academic and professional aspirations. In particular, your articles, "Lending a hand: Detecting hands and recognizing activities in complex egocentric interactions" and "DoTA: Unsupervised detection of traffic anomaly in driving videos," have captured my attention, highlighting your innovative use of segmentation techniques and CNN architecture.

What's more, I bring a diverse skill set to the table. I have experience in developing recommendation engines, GIS applications, linguistic resources, and ML models for various AI-related projects, including conversational AI, NLP, computer vision, and credit risk modeling.

I am eager to delve deeper into your research and would like to express my interest in becoming a part of your research group. If you are currently considering new students, I would be honored to be considered.

Enclosed with this email, you will find my resume, offering a comprehensive overview of my completed projects and research experience, along with my academic transcript. Please do not hesitate to reach out if you require any further information or would like to discuss my research interests in more detail. I am available for a call at your convenience.

Thank you for considering my application, and I look forward to the possibility of working with you.

Warm Regards,
Mobasshir Bhuiya Shagor

"""

# %%
prompt = f"""
Identify the following items from the email text: 
- What will be the professors sentiment after reading this email? (positive or negative)
- Is the reviewer(professor) expressing anger? (true or false)
- What could be the ideal format for this email?
- How would you rewrite this email as a perfect one?

The email is delimited with triple backticks. \
Format your response as a JSON object with \
"Sentiment", "Anger", "Format" and "New Email" as the keys.
If the information isn't present, use "unknown" \
as the value.
Make your response as short as possible.
Format the Anger value as a boolean.

Review text: '''{email}'''
"""
response = get_completion(prompt)
print(response)

# %%
rp_1_title = input("Research Paper 1 => Title")
rp_1_abstract = input("Research Paper 1 => Abstract")
rp_2_title = input("Research Paper 2 => Title")
rp_2_abstract = input("Research Paper 2 => Abstract")
reseach_papers = f"""
Research Paper 1
=================
Title: {rp_1_title}
Abstract: {rp_1_abstract}

Research Paper 2
=================
Title: {rp_2_title}
Abstract: {rp_2_abstract}
"""
print(reseach_papers)

# %%
prompt = f"""
Identify the following items from the research papers text: 
- Summary of the researches with individual presentation 
- Summarize these researches in a combine response
- Find out the key factors of these researches

The research papers are delimited with triple backticks. \
Format your response as a JSON object with \
"Individual Summary", "Combine Summary", "Key Factors" as the keys.
If the information isn't present, use "unknown" \
as the value.
Make your response as short as possible.

Research Papers: '''{reseach_papers}'''
"""
response = get_completion(prompt)
print(response)

# %%
rp_1_title = input("Research Paper 1 (Title)\n")
rp_1_abstract = input("Research Paper 1 (Abstract)\n")
rp_2_title = input("Research Paper 2 (Title)\n")
rp_2_abstract = input("Research Paper 2 (Abstract)\n")
Professors_reseach_papers = f"""
Research Paper 1
=================
Title: {rp_1_title}
Abstract: {rp_1_abstract}

Research Paper 2
=================
Title: {rp_2_title}
Abstract: {rp_2_abstract}
"""
print(Professors_reseach_papers)

# %%
prompt = f"""
Identify the following items from the research papers text: 
- Concise summary of the researches with individual presentation 
- Summarize these researches in a combine response
- Find out the key factors of these researches with individual presentation 

The research papers are delimited with triple backticks. \
Format your response as a JSON object with \
"Individual Summary", "Combine Summary", "Key Factors" as the keys.
If the information isn't present, use "unknown" \
as the value.
Make your response as short as possible.

Research Papers: '''{Professors_reseach_papers}'''
"""
response = get_completion(prompt)
print(response)

# %%
style = """
I have had the opportunity to explore your research, which closely aligns with my academic and professional aspirations. In particular, your articles, "Systems and methods for training object detection models using adversarial examples" and "Multitask Learning Via Interleaving: A Neural Network Investigation" have captured my attention, highlighting your innovative use of techniques such as multitask learning via interleaving, better memory consolidation with interleaved training, and the momentum optimizer by resetting momentum following a task switch. Furthermore, your patent systems and methods for training object detection models using adversarial examples greatly piqued my interest.
"""

# %%
prompt = f"""
Identify the following items from the research papers text: 
- Concise summary of the researches with individual presentation 
- Summarize these researches in a combine response
- Find out the key factors of these researches with individual presentation
- Summarize these research papers in a combine response imitating this writing style

The research papers are delimited with triple backticks. \
The style is delimited with four backticks. \
Format your response as a JSON object with \
"Individual Summary", "Combine Summary", "Key Factors" and "Styled Summary" as the keys.
If the information isn't present, use "unknown" \
as the value.
Make your response as short as possible.

Research Papers: '''{Professors_reseach_papers}'''
Writing Style: ''''{style}''''
"""
response = get_completion(prompt)
print(response)
